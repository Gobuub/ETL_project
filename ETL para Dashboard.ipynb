# %%
#!pip install fuzzywuzzy

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
journey = pd.read_csv('./data/pruebas/comunio_J26.csv')

# %%
journey = journey.drop(['Last_5_games_points'], axis=1)

# %%
gk = journey.loc[j25['Position']=='PT'].sort_values('Total_Points', ascending=False)[0:5]
df = journey.loc[j25['Position']=='DF'].sort_values('Total_Points', ascending=False)[0:10]
md = journey.loc[j25['Position']=='MD'].sort_values('Total_Points', ascending=False)[:10]
dl = journey.loc[j25['Position']=='DL'].sort_values('Total_Points', ascending=False)[:10]

# %%
top_players = pd.DataFrame(gk)

# %%
top_players = top_players.append(df)

# %%
top_players = top_players.append(md)
top_players = top_players.append(dl)

# %%
top_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 454 to 113
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Team_id           35 non-null     int64
#  1   Team              35 non-null     object
#  2   Player            35 non-null     object
#  3   Position          35 non-null     object
#  4   Matchs            35 non-null     int64
#  5   On_start_%        35 non-null     int64
#  6   Goals             35 non-null     int64
#  7   Assists           35 non-null     int64
#  8   Total_Points      35 non-null     int64
#  9   Points_Average    35 non-null     float64
#  10  J_21              35 non-null     int64
#  11  J_22              35 non-null     int64
#  12  J_23              35 non-null     int64
#  13  J_24              35 non-null     int64
#  14  J_25              35 non-null     int64
#  15  Avg_last_5_games  35 non-null     float64
# ...

# %%
#top_players = top_players.rename(columns ={ 'J_16':'2021-12-03', 'J_17':'2021-12-10','J_18':'2021-12-17', 'J_19':'2021-12-21', 'J_20': '2022-01-01','Value':'2022-01-01(V)'})

# %%
top_players['Price_per_Total_Points'] = top_players['Value']/top_players.Total_Points

# %%
ppp = []
for value in top_players.Price_per_Total_Points:

    value = '{0:.2f}'.format(value)
    
    ppp.append(value)

# %%
top_players.Price_per_Total_Points = ppp

# %%
Price_per_Points_Last_5_J = top_players['Value']/ (top_players['J_22']+top_players['J_23']+ top_players['J_23']+top_players['J_24']+top_players['J_25'])

pppl5j = []

for value in Price_per_Points_Last_5_J:
    value = '{0:.2f}'.format(value)
    pppl5j.append(value)

top_players['Price_per_Point_Last_5_J']= pppl5j

# %%
top_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 454 to 113
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Team_id                   35 non-null     int64
#  1   Team                      35 non-null     object
#  2   Player                    35 non-null     object
#  3   Position                  35 non-null     object
#  4   Matchs                    35 non-null     int64
#  5   On_start_%                35 non-null     int64
#  6   Goals                     35 non-null     int64
#  7   Assists                   35 non-null     int64
#  8   Total_Points              35 non-null     int64
#  9   Points_Average            35 non-null     float64
#  10  J_21                      35 non-null     int64
#  11  J_22                      35 non-null     int64
#  12  J_23                      35 non-null     int64
#  13  J_24                      35 non-null     int64
# ...

# %%
top_players
# Out:
#      Team_id                       Team             Player Position  Matchs  \
# 454       19           RC Celta de Vigo      Matías Dituro       PT      25
# 179        8             Real Madrid CF           Courtois       PT      25
# 330       14              Villarreal CF              Rulli       PT      22
# 68         4  RCD Espanyol de Barcelona        Diego López       PT      24
# 303       13    Real Sociedad de Fútbol        Alex Remiro       PT      21
# 181        8             Real Madrid CF       Éder Militão       DF      24
# 45         3                 CA Osasuna  David García Zub.       DF      23
# 332       14              Villarreal CF         Pau Torres       DF      22
# 479       20                 Sevilla FC       Diego Carlos       DF      24
# 182        8             Real Madrid CF              Alaba       DF      23
# 480       20                 Sevilla FC       Marcos Acuña       DF      21
# ...

# %%
top_players.to_excel('data/comunio_tableau_J25.xlsx', sheet_name='top_players')

# %%
gk = journey.loc[j25['Position']=='PT'].sort_values('Avg_last_5_games', ascending=False)[0:5]
df = journey.loc[j25['Position']=='DF'].sort_values('Avg_last_5_games', ascending=False)[0:10]
md = journey.loc[j25['Position']=='MD'].sort_values('Avg_last_5_games', ascending=False)[:10]
dl = journey.loc[j25['Position']=='DL'].sort_values('Avg_last_5_games', ascending=False)[:10]
top_players_avg_last_5_J = pd.DataFrame(gk)
top_players_avg_last_5_J = top_players_avg_last_5_J.append(df)
top_players_avg_last_5_J = top_players_avg_last_5_J.append(md)
top_players_avg_last_5_J = top_players_avg_last_5_J.append(dl)
top_players_avg_last_5_J['Price_per_Total_Points'] = top_players_avg_last_5_J['Value']/top_players_avg_last_5_J.Total_Points
ppp = []
for value in top_players_avg_last_5_J.Price_per_Total_Points:

    value = '{0:.2f}'.format(value)
    
    ppp.append(value)
top_players_avg_last_5_J.Price_per_Total_Points = ppp
Price_per_Points_Last_5_J = top_players_avg_last_5_J['Value']/ (top_players_avg_last_5_J['J_22']+top_players_avg_last_5_J['J_23']+ top_players_avg_last_5_J['J_23']+top_players_avg_last_5_J['J_24']+top_players_avg_last_5_J['J_25'])

pppl5j = []

for value in Price_per_Points_Last_5_J:
    value = '{0:.2f}'.format(value)
    pppl5j.append(value)

top_players_avg_last_5_J['Price_per_Point_Last_5_J']= pppl5j
top_players_avg_last_5_J
# Out:
#      Team_id                       Team             Player Position  Matchs  \
# 43         3                 CA Osasuna     Sergio Herrera       PT      24
# 303       13    Real Sociedad de Fútbol        Alex Remiro       PT      21
# 179        8             Real Madrid CF           Courtois       PT      25
# 402       17                   Cádiz CF   Jeremías Ledesma       PT      25
# 330       14              Villarreal CF              Rulli       PT      22
# 332       14              Villarreal CF         Pau Torres       DF      22
# 98         5               FC Barcelona         Jordi Alba       DF      18
# 181        8             Real Madrid CF       Éder Militão       DF      24
# 4          1              Athletic Club      Daniel Vivian       DF      13
# 45         3                 CA Osasuna  David García Zub.       DF      23
# 480       20                 Sevilla FC       Marcos Acuña       DF      21
# ...
