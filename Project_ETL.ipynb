# %%
import requests as req
import http.client
import json
import pandas as pd
from bs4 import BeautifulSoup as bs
from fuzzywuzzy import process, fuzz
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# C:\Users\botic\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Proyecto ETL Comunio
#
# ### Se pide:
#
# ###### Realizar un proyecto ETL con un tema de libre elección en la que se deben obtener datos con al menos 2 tipos técnicas de extracción
# ###### diferentes y desde al menos tres tipos de fuentes de datos distintas.
#
# ### Descripción del proyecto:
#
# Vamos a realizar un proyecto de ETL sobre el fantasy de fútbol Comunio, con el que buscamos obtener los siguientes
# tipos de datos.
#
# Tabla de Equipos de La Liga. ( Id. , Nombre Equipo) .
#
# Tabla de Jugadores.
#
# (Id Jugador, Id del equipo, Posición, Partidos Jugados 21/22, Goles, Asistencias, Puntos Comunio, Precio de mercado comunio, Puntos totales temporada 20/21 comunio, Pts ultimas 5 jornadas, Pts de media del campeonato,
# ptos de media de las últimas 5 jornadas).
#
# Fuentes:
#
# Tabla Equipos desde API. api.football-data.org
#
# Estadisticas de jugadores (partidos jugados, goles y asistencias) web scraping desde espn.
#
# Datos de comunio (Nombre, posición, valor, puntos, ... ). web scraping página comuniazo y comuniate.
#
# Se entrega notebook en el que se obtendran diferentes archivos con los que trabajar:
#     1 csv con los equipos de la liga.
#     1 csv por equipo con los datos de los jugadores de la plantilla
#     1 csv con los datos de todos los jugadores de la liga
#     1 json con los datos de todos los jugadores de la liga
#
# ------------------------------------------------------------------------------------------------------------------
# ### It is requested:
#
# ###### Carry out an ETL project with a subject of free choice in which data must be obtained with at least 2 types of extraction techniques
# ###### different and from at least three different types of data sources.
#
# ### Project description:
#
# We are going to carry out an ETL project on the football fantasy Comunio, with which we seek to obtain the following
# type of data.
#
# La Liga Team Table. (Id., Team Name).
#
# Players table.
#
# (Player Id, Team Id, Position, Matches Played 21/22, Goals, Assists, Community Points, Community Market Price, Total Season 20/21 Community Points, Pts in the last 5 days, Average Pts of the championship,
# average pts of the last 5 days).
#
# Sources:
#
# Table Equipment from API. api.football-data.org
#
# Player statistics (games played, goals and assists) web scraping from espn.
#
# Community data (Name, position, value, points, ...). web scraping page comuniazo and comuniate.
#
# Notebook is delivered in which different files will be obtained with which to work:
#     1 csv with league teams.
#     1 csv per team with the data of the players in the squad
#     1 csv with the data of all the players in the league
#     1 json with the data of all the players in the league

# %%
# Firts we realice the connection to the API, with the instructions describes in its documentation.
connection = http.client.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': '2643e9e1f8624a75a8eb21f12ad5c0bf' } # personal token given by the API.
connection.request('GET', '/v2/competitions/PD/teams?season=2021', None, headers ) # request for teams names
response = json.loads(connection.getresponse().read().decode())['teams'] #
team_lst = [response[t]['name'] for t in range(len(response))] # create a list of the teams
team_id = [i for i in range(1,21)] # create a list to give an id to each team
df_teams = pd.DataFrame(team_lst, columns = ['Team']) # create a Data Frame with the teams.
df_teams.insert(0, 'Team_id', team_id) # add column id to the Data Frame
df_teams.to_csv('data/teams20-21.csv', index=False) # export df to a csv file.

# %%
'''
    In this cell we create a var with type list for each team with the nexts paramas:
        - index[0] : Name of the team from the var team_lst
        - index[1] : Team id from the var team_id
        - index[2] : url of comuniate that give us almost of the data 
                    (Player name, Position, Season Points, Season Points Average, Value, On start average)
        - index[3] : url of comuniazo that give us the points of the last 5 matchs of the each player on the squad
        - index[4] : url of espn that give us the matchs played, goals received (goalkeepers), goals, assists.
        
    Then we store all of the vars in a list to give it like a param to the main function.
    
'''

ath_b = [team_lst[0], team_id[0], 'https://www.comuniate.com/plantilla/1/athletic', 'https://www.comuniazo.com/comunio-apuestas/equipos/athletic', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/93/esp.athletic_bilbao']
at_m = [team_lst[1], team_id[1], 'https://www.comuniate.com/plantilla/2/atletico', 'https://www.comuniazo.com/comunio-apuestas/equipos/atletico', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/1068/esp.atletico_madrid']
osa = [team_lst[2], team_id[2], 'https://www.comuniate.com/plantilla/12/osasuna', 'https://www.comuniazo.com/comunio-apuestas/equipos/osasuna', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/97/esp.osasuna']
rcd_esp = [team_lst[3], team_id[3], 'https://www.comuniate.com/plantilla/7/espanyol', 'https://www.comuniazo.com/comunio-apuestas/equipos/espanyol', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/88/esp.espanyol']
barc = [team_lst[4], team_id[4], 'https://www.comuniate.com/plantilla/3/barcelona', 'https://www.comuniazo.com/comunio-apuestas/equipos/barcelona', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/83/esp.barcelona']
geta = [team_lst[5], team_id[5], 'https://www.comuniate.com/plantilla/8/getafe', 'https://www.comuniazo.com/comunio-apuestas/equipos/getafe', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/2922/esp.getafe']
grana = [team_lst[6], team_id[6], 'https://www.comuniate.com/plantilla/71/granada', 'https://www.comuniazo.com/comunio-apuestas/equipos/granada', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/3747/esp.granada_cf']
r_mad = [team_lst[7], team_id[7], 'https://www.comuniate.com/plantilla/15/real-madrid', 'https://www.comuniazo.com/comunio-apuestas/equipos/real-madrid', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/86/esp.real_madrid']
rayo = [team_lst[8], team_id[8], 'https://www.comuniate.com/plantilla/70/rayo-vallecano', 'https://www.comuniazo.com/comunio-apuestas/equipos/rayo-vallecano', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/101/esp.rayo_vallecano']
leva = [team_lst[9], team_id[9], 'https://www.comuniate.com/plantilla/10/levante', 'https://www.comuniazo.com/comunio-apuestas/equipos/levante', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/1538/esp.levante']
mall = [team_lst[10], team_id[10], 'https://www.comuniate.com/plantilla/11/mallorca', 'https://www.comuniazo.com/comunio-apuestas/equipos/mallorca', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/84/esp.mallorca']
bet = [team_lst[11], team_id[1], 'https://www.comuniate.com/plantilla/4/betis', 'https://www.comuniazo.com/comunio-apuestas/equipos/betis', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/244/esp.betis_sevilla']
r_soc = [team_lst[12], team_id[12], 'https://www.comuniate.com/plantilla/13/real-sociedad', 'https://www.comuniazo.com/comunio-apuestas/equipos/real-sociedad', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/89/esp.real_sociedad']
villa = [team_lst[13], team_id[13], 'https://www.comuniate.com/plantilla/19/villarreal', 'https://www.comuniazo.com/comunio-apuestas/equipos/villarreal', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/102/esp.villarreal']
val = [team_lst[14], team_id[14], 'https://www.comuniate.com/plantilla/18/valencia', 'https://www.comuniazo.com/comunio-apuestas/equipos/valencia', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/94/esp.valencia']
alav = [team_lst[15], team_id[15], 'https://www.comuniate.com/plantilla/89/alaves', 'https://www.comuniazo.com/comunio-apuestas/equipos/alaves', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/96/esp.alaves']
cadi = [team_lst[16], team_id[16], 'https://www.comuniate.com/plantilla/105/cadiz', 'https://www.comuniazo.com/comunio-apuestas/equipos/cadiz', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/3842/esp.cadiz']
elch = [team_lst[17], team_id[17], 'https://www.comuniate.com/plantilla/75/elche', 'https://www.comuniazo.com/comunio-apuestas/equipos/elche', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/3751/esp.elche']
celta = [team_lst[18], team_id[18], 'https://www.comuniate.com/plantilla/5/celta', 'https://www.comuniazo.com/comunio-apuestas/equipos/celta', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/85/esp.celta_vigo']
sevil = [team_lst[19], team_id[19], 'https://www.comuniate.com/plantilla/17/sevilla', 'https://www.comuniazo.com/comunio-apuestas/equipos/sevilla', 'https://espndeportes.espn.com/futbol/equipo/plantel/_/id/243/esp.fc_sevilla']

teams_set = [ath_b, at_m, osa, rcd_esp, barc, geta, grana, r_mad, rayo, leva, mall, bet, r_soc, villa, val, alav, cadi,elch,celta, sevil]
#teams_set = [cadi]

# %%
def comunio_stats(team_lst, journey):
    '''
    Description.
    ------------
    
    With this function we want to obtain a dataset from diferents sources with the stadistics of all players of
    La Liga, to value its performance across the season.
    
    Params.
    -------
    
    The function receives a list with the teams of La Liga, and a the  journey's match.
    The team from teams_lst is a list with some variables:
        
        - index[0] : Name of the team from the var team_lst
        - index[1] : Team id from the var team_id
        - index[2] : url of comuniate that give us almost of the data 
                    (Player name, Position, Season Points, Season Points Average, Value, On start average)
        - index[3] : Number of players in the squad.
        - index[4] : url of comuniazo that give us the points of the last 5 matchs of the each player on the squad
        - index[5] : url of espn that give us the matchs played, goals received (goalkeepers), goals, assists.
    
    Journey's Macht only works from actually journey to future journeys (we can't obtains data from past journeys with this script)
    
    Returns.
    --------
        Prints the name of the team with each iteration.
        When script finish , returns 'Finished'
        Store in 'data' directory this files:
        
            1 csv file with teams of La Liga, 'data/teams.csv'.
            1 csv file with the player's squad for each team, 'data/team_name_J_number_of_journey.csv'.
            1 csv file with all the player's stats of La Liga.
            1 json file with all the player's stats of La Liga.
    
    '''
    
    df_teams = pd.DataFrame()
    
    for team in team_lst:
        
        print(team[0])
        
        soup = bs(req.get(team[2]).text , 'html.parser') # soup from comuniate web
        soup2 = bs(req.get(team[3]).text , 'html.parser') # soup from comuniazo web
        soup3 = bs(req.get(team[4]).text , 'html.parser') # soup from espn web
        
        num_players = soup.find_all('div', class_='col-md-12') # Firts count the players on the squad
        total_players = 0
        for i in range (2,6):
            # This loop sum the number of player for position on the squad
            total_players += len(num_players[i].find_all('div', 
                                                         class_='enlace2 ficha_jugador col-md-6 col-sm-6 col-xs-12'))
        
        players = total_players

        team_id = team[1]

        squad = team[0] # this line give us the name of the team
        
        # With this lines get the names of the playes
        name = soup.find_all('strong')
        name = [name[i].text for i in range(22, (22 + players * 2), 2)]
        
        # With this lines we want to get the position of the players
        pos_gk = soup.find_all('span', class_='label-posicion label-success')
        gks = [pos_gk[i].text.strip() for i in range(len(pos_gk))]

        pos_df = soup.find_all('span', class_='label-posicion label-info')
        dfs = [pos_df[i].text.strip() for i in range(len(pos_df))]

        pos_md = soup.find_all('span', class_='label-posicion label-warning')
        mds = [pos_md[i].text.strip() for i in range(len(pos_md))]

        pos_fw = soup.find_all('span', class_='label-posicion label-danger')
        fws = [pos_fw[i].text.strip() for i in range(len(pos_fw))]
    
        # Create an unique array for the positions of the players for arrays of the same length
        all_pos = gks + dfs + mds + fws
        
        # This lines get the total points on the season of the players
        pts = soup.find_all('span', class_='texto_pequenio2 label-posicion label-primary')
        pt = [pts[i].text for i in range(len(pts))]
        
        # This lines get the fantasy market value of the players
        values = soup.find_all('small')
        value = [values[i].text.split('€')[0].replace('.','') for i in range(0,len(values),3)]
        
        # This line get the average points of the players along the season
        pt_avg = [values[i].text.split()[-1] for i in range(1,len(values),3)]
        
        # This line get the percentage of the games that player are on the initial 11
        on_start_per = [values[i].text.split('%')[0] for i in range(2,len(values),3)]
        
        # With this line get a list of the points in the last five matchs
        points = soup2.find_all('div', class_='streak')
        pts_last_five_jouyneys = [points[i].text.split() for i in range(len(points))] 
        
        # Create variables to get a single value for each game of the last five games
        jback5 = []
        jback4 = []
        jback3 = []
        jback2 = []
        jback1 = []
        avg_last_5 = []
        
        # in this loop we iterate on each index of each list from pts_last_five_journeys to store the points
        # in an individual var and change type of this var to int for calculate the avg of the last 5 games
        # if the player have a '-' simbol we give o points, he don't play but we use 0 to calculate de avg
        
        for i, ptos in enumerate(pts_last_five_jouyneys):
            
            avg = 0
            
            if pts_last_five_jouyneys[i][0] == '-':
                jback5.append(0)
            else:
                jback5.append(int(pts_last_five_jouyneys[i][0]))
                avg += int(pts_last_five_jouyneys[i][0])
            
            if pts_last_five_jouyneys[i][1] == '-':
                jback4.append(0)
            else:
                jback4.append(int(pts_last_five_jouyneys[i][1]))
                avg += int(pts_last_five_jouyneys[i][1])
            
            if pts_last_five_jouyneys[i][2] == '-':
                jback3.append(0)
            else:
                jback3.append(int(pts_last_five_jouyneys[i][2]))
                avg += int(pts_last_five_jouyneys[i][2])
            
            if pts_last_five_jouyneys[i][3] == '-':
                jback2.append(0)
            else:
                jback2.append(int(pts_last_five_jouyneys[i][3]))
                avg += int(pts_last_five_jouyneys[i][3])
            
            if pts_last_five_jouyneys[i][4] == '-':
                jback1.append(0)
            else:
                jback1.append(int(pts_last_five_jouyneys[i][4]))
                avg += int(pts_last_five_jouyneys[i][4])

            avg_last_5.append(avg/5)        


        journey = journey
        
        # Create a dictionary to store stats from each player on each iteration
        
        team = {'Team_id': team_id, 
                'Team': squad, 
                'Player': name,
                'Position': all_pos,
                'Total_Points': pt,
                'Points_Average': pt_avg,
                'Value': value,
                'On_start_%': on_start_per,
                'Last_5_games_points': pts_last_five_jouyneys,
                f'J_{journey - 4}': jback5,
                f'J_{journey - 3}': jback4,
                f'J_{journey - 2}': jback3,
                f'J_{journey - 1}': jback2,
                f'J_{journey}': jback1,
                'Avg_last_5_games': avg_last_5}
        
        df = pd.DataFrame(team)
        
        # Second part of web scrapping to complete the stats table, with games played, goals or goal received(gk), and assists

        goalkeepers = soup3.find('div', class_='Table__Scroller')
        goalkeepers_rows = goalkeepers.find_all('tr')
        goalkeepers_stats = [[e.text for e in goalkeepers_rows[i].find_all('td')] for i in range(1,len(goalkeepers_rows))]

        team_squad = soup3.find_all('div', class_='Table__Scroller')
        team_squad_rows = team_squad[1].find_all('tr')
        team_squad_stats = [[e.text for e in team_squad_rows[i].find_all('td')] for i in range(1,len(team_squad_rows))]
        
        # In this list we store two dictionaries with others stats to merge with the previous dictionarie
        
        pl_lst = []

        for i, player in enumerate(goalkeepers_stats):
            
            name = ''.join([e for e in goalkeepers_stats[i][0] if e.isalpha() or e == ' '])
            
            if player[6] == '--': # this conditionals are for clean this serie and give correct type
                matches = 0
            else:
                matches = player[6]
            
            if player[9] == '--':
                goals_received = 0
            else:
                goals_received = player[9]
            
            if player[10] == '--':
                assists = 0
            else:
                assists = player[10]


            gk_dict = {'Player': name, 'Matches_Played': matches, 'Goals_/_Goals_Received': goals_received, 'Assists' : assists}
            pl_lst.append(gk_dict)

        for i, player in enumerate(team_squad_stats):
            
            name = ''.join([e for e in team_squad_stats[i][0] if e.isalpha() or e == ' '])
            
            if player[6]=='--':# this conditionals are for clean this serie and give correct type
                matches = 0
            else:
                matches = player[6]
            
            if player[8] == '--':
                goals = 0
            else:
                goals = player[8]
            
            if player[9] == '--':
                assists = 0
            else:
                assists = player[9]


            pl_dict = {'Player': name, 'Matches_Played': matches, 'Goals_/_Goals_Received': goals, 'Assists' : assists}
            pl_lst.append(pl_dict)
        
        df_stats = pd.DataFrame(pl_lst)
        
        # In this part of script we use the fuzzywuzzy lib to merge both dataframes.
        
        #This part compares both dataframes and returns a score of match in the serie that we want
        # In this case we compare the serie 'Player' of both dataframes
        df[['team_matched', 'fuzz_score']]=df.Player.apply(lambda x:process.extractOne(x,
                                                                     df_stats.Player.tolist(),
                                                                     scorer=fuzz.partial_ratio)).apply(pd.Series)
        
        # merge the both daframes
        df=pd.merge(df, df_stats, left_on='team_matched', right_on='Player')
        
        # Create a new datafram only with the values of fuzzy score are greater than 85
        df_1=df[df.fuzz_score>85]
        
        #The next line drops the columns that not are necessary on dataframe
        df_1 = df_1.drop(columns = ['team_matched', 'fuzz_score', 'Player_y'])
        
        # Rename the columns to the value that we want
        df_1 = df_1.rename(columns = {'Player_x': 'Player'})
        
        # order columns of the data frame to give sense
        order_col = [0,1,2,3,15,7,16,17,4,5,8,9,10,11,12,13,14,6]
        
        # Sort the dataframe columns with the value that we want
        df_1 = df_1[df_1.columns[order_col]]
        
        df_teams = df_teams.append(df_1) # add the df of the team to the df of all teams
        
        df_1.to_csv(f'data/{squad}_J{journey}.csv', index=False) # export df_team to a team file
    
    
    df_teams.to_json(f'data/comunio_J{journey}.json', orient="table") # export df of all teams to json file
    df_teams.to_csv(f'data/comunio_J{journey}.csv', index=False) # export df o all teams to csv file
    
    return 'Finished'

# %%
comunio_stats(teams_set,18)
# Out:
# Athletic Club
# Club Atlético de Madrid
# CA Osasuna
# RCD Espanyol de Barcelona
# FC Barcelona
# Getafe CF
# Granada CF
# Real Madrid CF
# Rayo Vallecano de Madrid
# Levante UD
# RCD Mallorca
# Real Betis Balompié
# Real Sociedad de Fútbol
# Villarreal CF
# Valencia CF
# Deportivo Alavés
# Cádiz CF
# Elche CF
# RC Celta de Vigo
# Sevilla FC
# 'Finished'

# %%
df_comunio = pd.read_csv(f'data/comunio_J18.csv')
df_comunio
# Out:
#      Team_id                       Team                 Player Position  \
# 0          1              Athletic Club             Unai Simón       PT
# 1          1              Athletic Club           Agirrezabala       PT
# 2          1              Athletic Club                Ezkieta       PT
# 3          1              Athletic Club         Iñigo Martínez       DF
# 4          1              Athletic Club                  Lekue       DF
# 5          1              Athletic Club             Balenziaga       DF
# 6          1              Athletic Club          Yeray Álvarez       DF
# 7          1              Athletic Club              De Marcos       DF
# 8          1              Athletic Club             Unai Núñez       DF
# 9          1              Athletic Club       Álex Petxarroman       DF
# 10         1              Athletic Club         Yuri Berchiche       DF
# 11         1              Athletic Club                   Capa       DF
# 12         1              Athletic Club             Nolaskoain       DF
# 13         1              Athletic Club                Muniain       MD
# 14         1              Athletic Club          Unai Vencedor       MD
# 15         1              Athletic Club                 Sancet       MD
# 16         1              Athletic Club          Nico Williams       MD
# 17         1              Athletic Club            Dani García       MD
# 18         1              Athletic Club         Álex Berenguer       MD
# 19         1              Athletic Club                Zarraga       MD
# 20         1              Athletic Club            Mikel Vesga       MD
# 21         1              Athletic Club           Jon Morcillo       MD
# 22         1              Athletic Club               Williams       DL
# 23         1              Athletic Club            Raúl García       DL
# 24         1              Athletic Club             Villalibre       DL
# 25         2    Club Atlético de Madrid                  Oblak       PT
# 26         2    Club Atlético de Madrid                Lecomte       PT
# 27         2    Club Atlético de Madrid                  Savic       DF
# 28         2    Club Atlético de Madrid           José Giménez       DF
# 29         2    Club Atlético de Madrid                 Felipe       DF
# 30         2    Club Atlético de Madrid          Mario Hermoso       DF
# 31         2    Club Atlético de Madrid               Trippier       DF
# 32         2    Club Atlético de Madrid             Renan Lodi       DF
# 33         2    Club Atlético de Madrid               Vrsaljko       DF
# 34         2    Club Atlético de Madrid        Rodrigo de Paul       MD
# 35         2    Club Atlético de Madrid                  Lemar       MD
# 36         2    Club Atlético de Madrid                   Koke       MD
# 37         2    Club Atlético de Madrid              Kondogbia       MD
# 38         2    Club Atlético de Madrid        Marcos Llorente       MD
# 39         2    Club Atlético de Madrid         Héctor Herrera       MD
# 40         2    Club Atlético de Madrid          Carlos Martín       MD
# 41         2    Club Atlético de Madrid                 Correa       DL
# 42         2    Club Atlético de Madrid            Luis Suárez       DL
# 43         2    Club Atlético de Madrid              Griezmann       DL
# 44         2    Club Atlético de Madrid          Matheus Cunha       DL
# 45         2    Club Atlético de Madrid             João Félix       DL
# 46         2    Club Atlético de Madrid               Saponjic       DL
# 47         3                 CA Osasuna         Sergio Herrera       PT
# 48         3                 CA Osasuna             Juan Pérez       PT
# 49         3                 CA Osasuna      David García Zub.       DF
# 50         3                 CA Osasuna            Nacho Vidal       DF
# 51         3                 CA Osasuna            Unai García       DF
# 52         3                 CA Osasuna        José Ángel Cote       DF
# 53         3                 CA Osasuna              Juan Cruz       DF
# 54         3                 CA Osasuna      Aridane Hernández       DF
# 55         3                 CA Osasuna            Jesús Areso       DF
# 56         3                 CA Osasuna                Ramalho       DF
# 57         3                 CA Osasuna            Lucas Torró       MD
# 58         3                 CA Osasuna          Jon Moncayola       MD
# 59         3                 CA Osasuna           Rubén García       MD
# 60         3                 CA Osasuna         Roberto Torres       MD
# 61         3                 CA Osasuna               Brasanac       MD
# 62         3                 CA Osasuna    Javi Martínez Calvo       MD
# 63         3                 CA Osasuna             Kike Barja       MD
# 64         3                 CA Osasuna            Kike García       DL
# 65         3                 CA Osasuna                   Oier       MD
# 66         3                 CA Osasuna            Iñigo Pérez       MD
# 67         3                 CA Osasuna          Robert Ibáñez       MD
# 68         3                 CA Osasuna              Ontiveros       MD
# 69         3                 CA Osasuna             Jaume Grau       MD
# 70         3                 CA Osasuna                Barbero       DL
# 71         3                 CA Osasuna         Ezequiel Ávila       DL
# 72         3                 CA Osasuna                Budimir       DL
# 73         4  RCD Espanyol de Barcelona            Diego López       PT
# 74         4  RCD Espanyol de Barcelona          Oier Olazábal       PT
# 75         4  RCD Espanyol de Barcelona            Sergi Gómez       DF
# 76         4  RCD Espanyol de Barcelona        Leandro Cabrera       DF
# 77         4  RCD Espanyol de Barcelona          Adrià Pedrosa       DF
# 78         4  RCD Espanyol de Barcelona            Aleix Vidal       DF
# 79         4  RCD Espanyol de Barcelona              Óscar Gil       DF
# 80         4  RCD Espanyol de Barcelona             Dídac Vilà       DF
# 81         4  RCD Espanyol de Barcelona                 Calero       DF
# 82         4  RCD Espanyol de Barcelona         Lluís Recasens       DF
# 83         4  RCD Espanyol de Barcelona               Miguelón       DF
# 84         4  RCD Espanyol de Barcelona     Rubén Sánchez Sáez       DF
# 85         4  RCD Espanyol de Barcelona           Sergi Darder       MD
# 86         4  RCD Espanyol de Barcelona                Embarba       MD
# 87         4  RCD Espanyol de Barcelona               Morlanes       MD
# 88         4  RCD Espanyol de Barcelona             Keidi Bare       MD
# 89         4  RCD Espanyol de Barcelona                Melendo       MD
# 90         4  RCD Espanyol de Barcelona         Yangel Herrera       MD
# 91         4  RCD Espanyol de Barcelona            David López       MD
# 92         4  RCD Espanyol de Barcelona                Vadillo       MD
# 93         4  RCD Espanyol de Barcelona            Fran Mérida       MD
# 94         4  RCD Espanyol de Barcelona                   Gori       MD
# 95         4  RCD Espanyol de Barcelona          Raúl de Tomás       DL
# 96         4  RCD Espanyol de Barcelona                 Wu Lei       DL
# 97         4  RCD Espanyol de Barcelona                 Dimata       DL
# 98         5               FC Barcelona             Ter Stegen       PT
# 99         5               FC Barcelona                   Neto       PT
# 100        5               FC Barcelona             Jordi Alba       DF
# 101        5               FC Barcelona                  Piqué       DF
# 102        5               FC Barcelona           Sergiño Dest       DF
# 103        5               FC Barcelona          Ronald Araujo       DF
# 104        5               FC Barcelona               Mingueza       DF
# 105        5               FC Barcelona            Eric García       DF
# 106        5               FC Barcelona                Lenglet       DF
# 107        5               FC Barcelona                 Umtiti       DF
# 108        5               FC Barcelona        Sergio Busquets       MD
# 109        5               FC Barcelona                De Jong       MD
# 110        5               FC Barcelona                   Gavi       MD
# 111        5               FC Barcelona               Coutinho       MD
# 112        5               FC Barcelona          Sergi Roberto       MD
# 113        5               FC Barcelona                  Pedri       MD
# 114        5               FC Barcelona                  Depay       DL
# 115        5               FC Barcelona              Ansu Fati       DL
# 116        5               FC Barcelona        Abde Ezzalzouli       DL
# 117        5               FC Barcelona           Luuk de Jong       DL
# 118        5               FC Barcelona            Braithwaite       DL
# 119        5               FC Barcelona                Dembélé       DL
# 120        5               FC Barcelona                  Demir       DL
# 121        5               FC Barcelona          Ferrán Jutglà       DL
# 122        5               FC Barcelona         Ilias Akhomach       DL
# 123        6                  Getafe CF            David Soria       PT
# 124        6                  Getafe CF            Rubén Yáñez       PT
# 125        6                  Getafe CF            Diego Conde       PT
# 126        6                  Getafe CF          Damián Suárez       DF
# 127        6                  Getafe CF        Mathías Olivera       DF
# 128        6                  Getafe CF           Jorge Cuenca       DF
# 129        6                  Getafe CF               Mitrovic       DF
# 130        6                  Getafe CF                  Djené       DF
# 131        6                  Getafe CF         Jonathan Silva       DF
# 132        6                  Getafe CF                 Cabaco       DF
# 133        6                  Getafe CF                  Chema       DF
# 134        6                  Getafe CF             Maksimovic       MD
# 135        6                  Getafe CF        Mauro Arambarri       MD
# 136        6                  Getafe CF                  Aleñá       MD
# 137        6                  Getafe CF        Florentino Luís       MD
# 138        6                  Getafe CF                 Jankto       MD
# 139        6                  Getafe CF                  Timor       MD
# 140        6                  Getafe CF                 Vitolo       MD
# 141        6                  Getafe CF                   Nyom       MD
# 142        6                  Getafe CF              Enes Ünal       DL
# 143        6                  Getafe CF         Sandro Ramírez       DL
# 144        6                  Getafe CF             Jaime Mata       DL
# 145        6                  Getafe CF           Darío Poveda       DL
# 146        6                  Getafe CF            José Macías       DL
# 147        6                  Getafe CF            Mamor Niang       DL
# 148        7                 Granada CF         Luís Maximiano       PT
# 149        7                 Granada CF        Aarón Escandell       PT
# 150        7                 Granada CF             João Costa       PT
# 151        7                 Granada CF          Ángel Jiménez       PT
# 152        7                 Granada CF         Germán Sánchez       DF
# 153        7                 Granada CF            Carlos Neva       DF
# 154        7                 Granada CF        Sergio Escudero       DF
# 155        7                 Granada CF             Luis Abram       DF
# 156        7                 Granada CF            Víctor Díaz       DF
# 157        7                 Granada CF        Domingos Duarte       DF
# 158        7                 Granada CF                  Quini       DF
# 159        7                 Granada CF                  Arias       DF
# 160        7                 Granada CF          Raúl Torrente       DF
# 161        7                 Granada CF           Pepe Sánchez       DF
# 162        7                 Granada CF          Sergio Barcia       DF
# 163        7                 Granada CF          Neyder Lozano       DF
# 164        7                 Granada CF             Luis Milla       MD
# 165        7                 Granada CF                Montoro       MD
# 166        7                 Granada CF                Rochina       MD
# 167        7                 Granada CF        Antonio Puertas       MD
# 168        7                 Granada CF               Gonalons       MD
# 169        7                 Granada CF          Darwin Machís       MD
# 170        7                 Granada CF           Alberto Soro       MD
# 171        7                 Granada CF                 Monchu       MD
# 172        7                 Granada CF              Yan Eteki       MD
# 173        7                 Granada CF              Isma Ruiz       MD
# 174        7                 Granada CF           Jorge Molina       DL
# 175        7                 Granada CF                  Bacca       DL
# 176        8             Real Madrid CF               Courtois       PT
# 177        8             Real Madrid CF                  Lunin       PT
# 178        8             Real Madrid CF                  Alaba       DF
# 179        8             Real Madrid CF           Éder Militão       DF
# 180        8             Real Madrid CF        Nacho Fernández       DF
# 181        8             Real Madrid CF               Carvajal       DF
# 182        8             Real Madrid CF          Ferland Mendy       DF
# 183        8             Real Madrid CF       Miguel Gutiérrez       DF
# 184        8             Real Madrid CF                Marcelo       DF
# 185        8             Real Madrid CF          Sergio Santos       DF
# 186        8             Real Madrid CF          Jesús Vallejo       DF
# 187        8             Real Madrid CF               Casemiro       MD
# 188        8             Real Madrid CF                  Kroos       MD
# 189        8             Real Madrid CF                 Modric       MD
# 190        8             Real Madrid CF          Lucas Vázquez       MD
# 191        8             Real Madrid CF              Camavinga       MD
# 192        8             Real Madrid CF                   Isco       MD
# 193        8             Real Madrid CF         Antonio Blanco       MD
# 194        8             Real Madrid CF          Dani Ceballos       MD
# 195        8             Real Madrid CF                Benzema       DL
# 196        8             Real Madrid CF        Vinícius Júnior       DL
# 197        8             Real Madrid CF                Asensio       DL
# 198        8             Real Madrid CF            Eden Hazard       DL
# 199        8             Real Madrid CF                Rodrygo       DL
# 200        8             Real Madrid CF                  Jovic       DL
# 201        8             Real Madrid CF                   Bale       DL
# 202        8             Real Madrid CF           Mariano Díaz       DL
# 203        9   Rayo Vallecano de Madrid           Dimitrievski       PT
# 204        9   Rayo Vallecano de Madrid          Iván Arboleda       PT
# 205        9   Rayo Vallecano de Madrid            Luca Zidane       PT
# 206        9   Rayo Vallecano de Madrid                 Catena       DF
# 207        9   Rayo Vallecano de Madrid            Fran García       DF
# 208        9   Rayo Vallecano de Madrid                 Balliu       DF
# 209        9   Rayo Vallecano de Madrid              Saveljich       DF
# 210        9   Rayo Vallecano de Madrid        Mario Hernández       DF
# 211        9   Rayo Vallecano de Madrid           Nikola Maras       DF
# 212        9   Rayo Vallecano de Madrid        Kevin Rodrigues       DF
# 213        9   Rayo Vallecano de Madrid          Álvaro García       MD
# 214        9   Rayo Vallecano de Madrid                  Trejo       MD
# 215        9   Rayo Vallecano de Madrid               Comesaña       MD
# 216        9   Rayo Vallecano de Madrid            Isi Palazón       MD
# 217        9   Rayo Vallecano de Madrid         Óscar Valentín       MD
# 218        9   Rayo Vallecano de Madrid            Randy Nteka       MD
# 219        9   Rayo Vallecano de Madrid                   Bebé       MD
# 220        9   Rayo Vallecano de Madrid             Pathé Ciss       MD
# 221        9   Rayo Vallecano de Madrid             Unai López       MD
# 222        9   Rayo Vallecano de Madrid             Merquelanz       MD
# 223        9   Rayo Vallecano de Madrid                   Pozo       MD
# 224        9   Rayo Vallecano de Madrid           Mario Suárez       MD
# 225        9   Rayo Vallecano de Madrid                 Falcao       DL
# 226        9   Rayo Vallecano de Madrid        Sergi Guardiola       DL
# 227        9   Rayo Vallecano de Madrid          Andrés Martín       DL
# 228        9   Rayo Vallecano de Madrid           Yacine Qasmi       DL
# 229        9   Rayo Vallecano de Madrid          Sergio Moreno       DL
# 230       10                 Levante UD        Aitor Fernández       PT
# 231       10                 Levante UD             Rúben Vezo       DF
# 232       10                 Levante UD                Mustafi       DF
# 233       10                 Levante UD                  Clerc       DF
# 234       10                 Levante UD                    Son       DF
# 235       10                 Levante UD           Óscar Duarte       DF
# 236       10                 Levante UD          Jorge Miramón       DF
# 237       10                 Levante UD        Enric Franquesa       DF
# 238       10                 Levante UD         Sergio Postigo       DF
# 239       10                 Levante UD                   Coke       DF
# 240       10                 Levante UD            Marc Pubill       DF
# 241       10                 Levante UD                Campaña       MD
# 242       10                 Levante UD                 Bardhi       MD
# 243       10                 Levante UD        Jorge de Frutos       MD
# 244       10                 Levante UD          Mickael Malsa       MD
# 245       10                 Levante UD                 Melero       MD
# 246       10                 Levante UD         Pablo Martínez       MD
# 247       10                 Levante UD      Alejandro Cantero       MD
# 248       10                 Levante UD                 Pepelu       MD
# 249       10                 Levante UD                 Radoja       MD
# 250       10                 Levante UD               Vukcevic       MD
# 251       10                 Levante UD         Edgar Sevikyan       MD
# 252       10                 Levante UD                Morales       DL
# 253       10                 Levante UD                  Roger       DL
# 254       10                 Levante UD             Dani Gómez       DL
# 255       10                 Levante UD                Soldado       DL
# 256       11               RCD Mallorca                  Reina       PT
# 257       11               RCD Mallorca                  Greif       PT
# 258       11               RCD Mallorca                 Maffeo       DF
# 259       11               RCD Mallorca         Martin Valjent       DF
# 260       11               RCD Mallorca           Franco Russo       DF
# 261       11               RCD Mallorca           Brian Oliván       DF
# 262       11               RCD Mallorca            Jaume Costa       DF
# 263       11               RCD Mallorca            Joan Sastre       DF
# 264       11               RCD Mallorca             Josep Gayá       DF
# 265       11               RCD Mallorca           Idrissu Baba       MD
# 266       11               RCD Mallorca      Ruiz de Galarreta       MD
# 267       11               RCD Mallorca          Salva Sevilla       MD
# 268       11               RCD Mallorca            Kang-In Lee       MD
# 269       11               RCD Mallorca                   Kubo       MD
# 270       11               RCD Mallorca        Antonio Sánchez       MD
# 271       11               RCD Mallorca      Rodrigo Battaglia       MD
# 272       11               RCD Mallorca                 Mboula       MD
# 273       11               RCD Mallorca            Aleix Febas       MD
# 274       11               RCD Mallorca                 Sedlar       MD
# 275       11               RCD Mallorca            Lago Júnior       MD
# 276       11               RCD Mallorca        Ángel Rodríguez       DL
# 277       11               RCD Mallorca          Fernando Niño       DL
# 278       11               RCD Mallorca            Abdón Prats       DL
# 279       11               RCD Mallorca                  Hoppe       DL
# 280        2        Real Betis Balompié              Rui Silva       PT
# 281        2        Real Betis Balompié          Claudio Bravo       PT
# 282        2        Real Betis Balompié            Joel Robles       PT
# 283        2        Real Betis Balompié            Álex Moreno       DF
# 284        2        Real Betis Balompié            Víctor Ruiz       DF
# 285        2        Real Betis Balompié        Héctor Bellerín       DF
# 286        2        Real Betis Balompié            Marc Bartra       DF
# 287        2        Real Betis Balompié               Pezzella       DF
# 288        2        Real Betis Balompié         Martín Montoya       DF
# 289        2        Real Betis Balompié           Juan Miranda       DF
# 290        2        Real Betis Balompié           Kike Hermoso       DF
# 291        2        Real Betis Balompié                 Sabaly       DF
# 292        2        Real Betis Balompié                  Fekir       MD
# 293        2        Real Betis Balompié           Yassin Fekir       MD
# 294        2        Real Betis Balompié                Canales       MD
# 295        2        Real Betis Balompié       William Carvalho       MD
# 296        2        Real Betis Balompié        Guido Rodríguez       MD
# 297        2        Real Betis Balompié         Édgar González       MD
# 298        2        Real Betis Balompié        Rodrigo Sánchez       MD
# 299        2        Real Betis Balompié               Guardado       MD
# 300        2        Real Betis Balompié                  Tello       MD
# 301        2        Real Betis Balompié                Joaquín       MD
# 302        2        Real Betis Balompié           Aitor Ruibal       MD
# 303        2        Real Betis Balompié               Camarasa       MD
# 304        2        Real Betis Balompié         Rober González       MD
# 305        2        Real Betis Balompié          Paul Akouokou       MD
# 306        2        Real Betis Balompié           Diego Lainez       MD
# 307        2        Real Betis Balompié         Juanmi Jiménez       DL
# 308        2        Real Betis Balompié           Willian José       DL
# 309        2        Real Betis Balompié         Borja Iglesias       DL
# 310       13    Real Sociedad de Fútbol            Alex Remiro       PT
# 311       13    Real Sociedad de Fútbol                   Ryan       PT
# 312       13    Real Sociedad de Fútbol             Le Normand       DF
# 313       13    Real Sociedad de Fútbol        Aritz Elustondo       DF
# 314       13    Real Sociedad de Fútbol              Gorosabel       DF
# 315       13    Real Sociedad de Fútbol               Zubeldia       DF
# 316       13    Real Sociedad de Fútbol            Aihen Muñoz       DF
# 317       13    Real Sociedad de Fútbol             Diego Rico       DF
# 318       13    Real Sociedad de Fútbol            Jon Pacheco       DF
# 319       13    Real Sociedad de Fútbol          Cristo Romero       DF
# 320       13    Real Sociedad de Fútbol                Monreal       DF
# 321       13    Real Sociedad de Fútbol              Oyarzabal       DL
# 322       13    Real Sociedad de Fútbol           Mikel Merino       MD
# 323       13    Real Sociedad de Fútbol                Januzaj       MD
# 324       13    Real Sociedad de Fútbol              Zubimendi       MD
# 325       13    Real Sociedad de Fútbol                  Silva       MD
# 326       13    Real Sociedad de Fútbol      Ander Barrenetxea       MD
# 327       13    Real Sociedad de Fútbol                Guevara       MD
# 328       13    Real Sociedad de Fútbol         Robert Navarro       MD
# 329       13    Real Sociedad de Fútbol       Beñat Turrientes       MD
# 330       13    Real Sociedad de Fútbol          Germán Valera       MD
# 331       13    Real Sociedad de Fútbol                 Guridi       MD
# 332       13    Real Sociedad de Fútbol           Illarramendi       MD
# 333       13    Real Sociedad de Fútbol                   Isak       DL
# 334       13    Real Sociedad de Fútbol                  Portu       DL
# 335       13    Real Sociedad de Fútbol                Sorloth       DL
# 336       13    Real Sociedad de Fútbol                 Lobete       DL
# 337       13    Real Sociedad de Fútbol       Carlos Fernández       DL
# 338       14              Villarreal CF                  Rulli       PT
# 339       14              Villarreal CF          Sergio Asenjo       PT
# 340       14              Villarreal CF             Pau Torres       DF
# 341       14              Villarreal CF         Alberto Moreno       DF
# 342       14              Villarreal CF                 Albiol       DF
# 343       14              Villarreal CF             Juan Foyth       DF
# 344       14              Villarreal CF              Estupiñán       DF
# 345       14              Villarreal CF            Aïssa Mandi       DF
# 346       14              Villarreal CF        Alfonso Pedraza       DF
# 347       14              Villarreal CF                 Aurier       DF
# 348       14              Villarreal CF             Rubén Peña       DF
# 349       14              Villarreal CF           Mario Gaspar       DF
# 350       14              Villarreal CF                 Parejo       MD
# 351       14              Villarreal CF                Danjuma       MD
# 352       14              Villarreal CF            Yéremi Pino       MD
# 353       14              Villarreal CF                 Capoue       MD
# 354       14              Villarreal CF              Trigueros       MD
# 355       14              Villarreal CF               Coquelin       MD
# 356       14              Villarreal CF              Moi Gómez       MD
# 357       14              Villarreal CF         Samu Chukwueze       MD
# 358       14              Villarreal CF                   Raba       MD
# 359       14              Villarreal CF                 Iborra       MD
# 360       14              Villarreal CF          Gerard Moreno       DL
# 361       14              Villarreal CF            Boulaye Dia       DL
# 362       14              Villarreal CF                Alcácer       DL
# 363       15                Valencia CF              Cillessen       PT
# 364       15                Valencia CF          Mamardashvili       PT
# 365       15                Valencia CF         Jaume Doménech       PT
# 366       15                Valencia CF        Cristian Rivero       PT
# 367       15                Valencia CF                   Gayà       DF
# 368       15                Valencia CF            Daniel Wass       DF
# 369       15                Valencia CF          Omar Alderete       DF
# 370       15                Valencia CF       Gabriel Paulista       DF
# 371       15                Valencia CF              Foulquier       DF
# 372       15                Valencia CF               Diakhaby       DF
# 373       15                Valencia CF              Guillamón       DF
# 374       15                Valencia CF        Thierry Correia       DF
# 375       15                Valencia CF                Piccini       DF
# 376       15                Valencia CF                   Lato       DF
# 377       15                Valencia CF          Jesús Vázquez       DF
# 378       15                Valencia CF           Rubén Iranzo       DF
# 379       15                Valencia CF           Carlos Soler       MD
# 380       15                Valencia CF                  Racic       MD
# 381       15                Valencia CF        Denis Cheryshev       MD
# 382       15                Valencia CF            Yunus Musah       MD
# 383       15                Valencia CF           Hélder Costa       MD
# 384       15                Valencia CF                   Koba       MD
# 385       15                Valencia CF                  Jason       MD
# 386       15                Valencia CF            Álex Blanco       MD
# 387       15                Valencia CF                 Guedes       DL
# 388       15                Valencia CF              Hugo Duro       DL
# 389       15                Valencia CF             Maxi Gómez       DL
# 390       15                Valencia CF           Manu Vallejo       DL
# 391       16           Deportivo Alavés                Pacheco       PT
# 392       16           Deportivo Alavés                 Sivera       PT
# 393       16           Deportivo Alavés              Laguardia       DF
# 394       16           Deportivo Alavés           Rubén Duarte       DF
# 395       16           Deportivo Alavés  Martín Aguirregabiria       DF
# 396       16           Deportivo Alavés                 Miazga       DF
# 397       16           Deportivo Alavés                Lejeune       DF
# 398       16           Deportivo Alavés           Ximo Navarro       DF
# 399       16           Deportivo Alavés      Alberto Rodríguez       DF
# 400       16           Deportivo Alavés            Saúl García       DF
# 401       16           Deportivo Alavés       Alexandru Tirlea       DF
# 402       16           Deportivo Alavés             Luis Rioja       MD
# 403       16           Deportivo Alavés           Mamadou Loum       MD
# 404       16           Deportivo Alavés     Manu García Alonso       MD
# 405       16           Deportivo Alavés              Toni Moya       MD
# 406       16           Deportivo Alavés           Edgar Méndez       MD
# 407       16           Deportivo Alavés             Tomás Pina       MD
# 408       16           Deportivo Alavés      Facundo Pellistri       MD
# 409       16           Deportivo Alavés              Pere Pons       MD
# 410       16           Deportivo Alavés            Iván Martín       MD
# 411       16           Deportivo Alavés                 Joselu       DL
# 412       16           Deportivo Alavés          Mamadou Sylla       DL
# 413       16           Deportivo Alavés               Guidetti       DL
# 414       16           Deportivo Alavés    Miguel de la Fuente       DL
# 415       17                   Cádiz CF       Jeremías Ledesma       PT
# 416       17                   Cádiz CF              David Gil       PT
# 417       17                   Cádiz CF                 Espino       DF
# 418       17                   Cádiz CF                   Fali       DF
# 419       17                   Cádiz CF       Varazdat Haroyan       DF
# 420       17                   Cádiz CF                  Akapo       DF
# 421       17                   Cádiz CF           Víctor Chust       DF
# 422       17                   Cádiz CF             Arzamendia       DF
# 423       17                   Cádiz CF                   Cala       DF
# 424       17                   Cádiz CF           Marcos Mauro       DF
# 425       17                   Cádiz CF         Álex Fernández       MD
# 426       17                   Cádiz CF          Tomás Alarcón       MD
# 427       17                   Cádiz CF           Jens Jonsson       MD
# 428       17                   Cádiz CF                  Salvi       MD
# 429       17                   Cádiz CF          Alberto Perea       MD
# 430       17                   Cádiz CF         Álvaro Jiménez       MD
# 431       17                   Cádiz CF        Martín Calderón       MD
# 432       17                   Cádiz CF         Álvaro Bastida       MD
# 433       17                   Cádiz CF             Iván Alejo       MD
# 434       17                   Cádiz CF              José Mari       MD
# 435       17                   Cádiz CF                Negredo       DL
# 436       17                   Cádiz CF                Sobrino       DL
# 437       17                   Cádiz CF                Osmajic       DL
# 438       17                   Cádiz CF           Iván Chapela       DL
# 439       17                   Cádiz CF          Florin Andone       DL
# 440       18                   Elche CF           Kiko Casilla       PT
# 441       18                   Elche CF            Édgar Badía       PT
# 442       18                   Elche CF            Axel Werner       PT
# 443       18                   Elche CF           Johan Mojica       DF
# 444       18                   Elche CF              Enzo Roco       DF
# 445       18                   Elche CF    Helibelton Palacios       DF
# 446       18                   Elche CF         Diego González       DF
# 447       18                   Elche CF                  Bigas       DF
# 448       18                   Elche CF          Gonzalo Verdú       DF
# 449       18                   Elche CF               Barragán       DF
# 450       18                   Elche CF                 Josema       DF
# 451       18                   Elche CF            John Donald       DF
# 452       18                   Elche CF                  Fidel       MD
# 453       18                   Elche CF         Omar Mascarell       MD
# 454       18                   Elche CF                  Josan       MD
# 455       18                   Elche CF              Raúl Guti       MD
# 456       18                   Elche CF                 Gumbau       MD
# 457       18                   Elche CF           Iván Marcone       MD
# 458       18                   Elche CF                Pastore       MD
# 459       18                   Elche CF                 Piatti       MD
# 460       18                   Elche CF             Lucas Boyé       DL
# 461       18                   Elche CF            Lucas Pérez       DL
# 462       18                   Elche CF              Benedetto       DL
# 463       18                   Elche CF             Pere Milla       DL
# 464       18                   Elche CF         Guido Carrillo       DL
# 465       19           RC Celta de Vigo           Rubén Blanco       PT
# 466       19           RC Celta de Vigo          Néstor Araujo       DF
# 467       19           RC Celta de Vigo         Jeison Murillo       DF
# 468       19           RC Celta de Vigo             Hugo Mallo       DF
# 469       19           RC Celta de Vigo                  Aidoo       DF
# 470       19           RC Celta de Vigo          Kevin Vázquez       DF
# 471       19           RC Celta de Vigo       Carlos Domínguez       DF
# 472       19           RC Celta de Vigo           Denis Suárez       MD
# 473       19           RC Celta de Vigo           Brais Méndez       MD
# 474       19           RC Celta de Vigo           Fran Beltrán       MD
# 475       19           RC Celta de Vigo           Franco Cervi       MD
# 476       19           RC Celta de Vigo           Renato Tapia       MD
# 477       19           RC Celta de Vigo         Augusto Solari       MD
# 478       19           RC Celta de Vigo           Okay Yokuslu       MD
# 479       19           RC Celta de Vigo           Hugo Álvarez       MD
# 480       19           RC Celta de Vigo           Miguel Baeza       MD
# 481       19           RC Celta de Vigo          Gabriel Veiga       MD
# 482       19           RC Celta de Vigo       Alfonso González       MD
# 483       19           RC Celta de Vigo             Iago Aspas       DL
# 484       19           RC Celta de Vigo             Santi Mina       DL
# 485       19           RC Celta de Vigo                 Nolito       DL
# 486       19           RC Celta de Vigo        Thiago Galhardo       DL
# 487       20                 Sevilla FC                   Bono       PT
# 488       20                 Sevilla FC              Dmitrovic       PT
# 489       20                 Sevilla FC           Diego Carlos       DF
# 490       20                 Sevilla FC           Marcos Acuña       DF
# 491       20                 Sevilla FC            Jesús Navas       DF
# 492       20                 Sevilla FC        Gonzalo Montiel       DF
# 493       20                 Sevilla FC           Augustinsson       DF
# 494       20                 Sevilla FC                  Rekik       DF
# 495       20                 Sevilla FC                Rakitic       MD
# 496       20                 Sevilla FC            Joan Jordan       MD
# 497       20                 Sevilla FC         Fernando Reges       MD
# 498       20                 Sevilla FC                Delaney       MD
# 499       20                 Sevilla FC             Papu Gómez       MD
# 500       20                 Sevilla FC        Óscar Rodríguez       MD
# 501       20                 Sevilla FC          Óliver Torres       MD
# 502       20                 Sevilla FC                 Gudelj       MD
# 503       20                 Sevilla FC            Pedro Ortiz       MD
# 504       20                 Sevilla FC            Erik Lamela       DL
# 505       20                 Sevilla FC               Rafa Mir       DL
# 506       20                 Sevilla FC                Ocampos       DL
# 507       20                 Sevilla FC              En-Nesyri       DL
# 508       20                 Sevilla FC       Munir El Haddadi       DL
# 509       20                 Sevilla FC                   Suso       DL
# 510       20                 Sevilla FC                Idrissi       DL
# 511       20                 Sevilla FC            Iván Romero       DL
#
#      Matches_Played  On_start_%  Goals_/_Goals_Received  Assists  \
# 0                15          83                      11        0
# 1                 3          17                       3        0
# 2                 0           0                       0        0
# 3                14          78                       2        0
# 4                18          94                       0        2
# 5                 0          78                       0        0
# 6                 9          50                       0        0
# 7                 0          28                       0        0
# 8                 6          22                       0        0
# 9                 4           0                       0        0
# 10                0           0                       0        0
# 11                0           0                       0        0
# 12                0           0                       0        0
# 13               17          94                       2        5
# 14               17          89                       0        0
# 15               14          33                       0        3
# 16               18          33                       0        0
# 17               17          83                       0        0
# 18               17          61                       0        1
# 19               14          17                       0        0
# 20                0          22                       0        0
# 21                7           0                       0        0
# 22                0          89                       0        0
# 23               17          72                       3        0
# 24                7           6                       0        0
# 25               17         100                      18        0
# 26                0           0                       0        0
# 27                0          76                       0        0
# 28               10          59                       0        0
# 29                0          47                       0        0
# 30               16          82                       0        1
# 31                0          59                       0        0
# 32               13          24                       0        0
# 33                6           6                       1        1
# 34               16          59                       0        1
# 35               11          47                       3        3
# 36                0          82                       0        0
# 37               12          41                       0        0
# 38               13          76                       0        1
# 39                8          12                       0        0
# 40                1           0                       0        0
# 41               17          71                       4        4
# 42                0          65                       0        0
# 43               16          88                       3        1
# 44               13          12                       3        1
# 45               10          18                       1        1
# 46                0           0                       0        0
# 47               17          94                      19        0
# 48                1           6                       2        0
# 49               17          94                       3        0
# 50                0          89                       0        0
# 51               13          67                       0        0
# 52               11          22                       1        1
# 53                0          33                       0        0
# 54                6          33                       0        0
# 55                2          11                       0        0
# 56                0           0                       0        0
# 57               15          83                       1        0
# 58                0          83                       0        0
# 59                0          78                       0        0
# 60               13          28                       2        2
# 61               18          83                       0        1
# 62               11          17                       1        0
# 63               16          33                       2        0
# 64               16          72                       2        0
# 65               14          28                       0        0
# 66                5          11                       1        0
# 67                4           6                       0        0
# 68                3           0                       0        0
# 69                1           0                       0        0
# 70                7           0                       0        0
# 71                0          39                       0        0
# 72                8          17                       1        0
# 73               18         100                      19        0
# 74                0           0                       0        0
# 75               17          94                       1        2
# 76               18         100                       1        0
# 77               17          94                       1        1
# 78               14          67                       2        0
# 79                9          50                       0        0
# 80                4           6                       0        0
# 81                2           6                       0        0
# 82                1           0                       0        0
# 83                2           6                       0        0
# 84                2           0                       0        0
# 85               17          94                       1        2
# 86               17          94                       0        2
# 87               16          33                       1        0
# 88               12          33                       0        1
# 89               10          44                       0        0
# 90                9          33                       1        1
# 91               10          33                       0        0
# 92                3           0                       0        0
# 93                4          11                       0        0
# 94                1           0                       0        0
# 95               17          94                       8        2
# 96               12          17                       0        0
# 97               12          17                       0        0
# 98                0          88                       0        0
# 99                2          12                       3        0
# 100              12          71                       0        4
# 101              14          71                       1        0
# 102              12          65                       0        3
# 103               0          47                       0        0
# 104               0          41                       0        0
# 105              12          71                       0        0
# 106               0          24                       0        0
# 107               0           6                       0        0
# 108               0         100                       0        0
# 109               0          76                       0        0
# 110               0          71                       0        0
# 111               0          29                       0        0
# 112               0          24                       0        0
# 113               0          12                       0        0
# 114              15          88                       8        2
# 115               5          18                       3        0
# 116               7          24                       1        0
# 117               0          18                       0        0
# 118               0          18                       0        0
# 119               0          12                       0        0
# 120               6          12                       0        0
# 121               0           6                       0        0
# 122               1           6                       0        0
# 123              18         100                      20        0
# 124               0           0                       0        0
# 125               0           0                       0        0
# 126              16          78                       0        3
# 127              16          89                       1        0
# 128              15          78                       1        0
# 129               0          72                       0        0
# 130              17          94                       0        0
# 131               7           0                       0        0
# 132               4          11                       0        1
# 133               1           6                       0        0
# 134              18         100                       0        1
# 135              15          83                       0        2
# 136              17          94                       0        2
# 137              10          28                       0        1
# 138               0          17                       0        0
# ...
# 205     0     0     0               0.0    440000
# 206     6     2    12               5.6   3230000
# 207     5     2     4               4.0   2460000
# 208     4     5     5               4.0   1480000
# 209     5     2     5               3.2   1470000
# 210     0     0     0               0.0    300000
# 211     0     0     0               0.0    470000
# 212     2     0     0               0.6    410000
# 213     7     6     7               6.6  10200000
# 214     2     3     5               4.8   9880000
# 215     0    -1     7               4.0   5450000
# 216     5     1     4               5.4   3560000
# 217     5     7     5               4.6   2570000
# 218     1     2     2               1.0   4700000
# 219     0     4     5               2.0   2240000
# 220     3     0     0               0.6   2870000
# 221     2     5     1               2.4   1650000
# 222     0     0     0               0.0   1090000
# 223     0     2     0               2.0    430000
# 224     0     0     0               0.0    500000
# 225     2     0     0               0.4  10250000
# 226     2     3    10               5.0   3290000
# 227     0     2     0               1.0    290000
# 228     0     0     0               0.0    640000
# 229     0     0     0               0.0    210000
# 230     0     0     0               0.0   2500000
# 231     7     2    -1               3.6   1870000
# 232     7     0     0               4.6   2420000
# 233     3     1     2               3.0   1360000
# 234     6     1     0               2.4    960000
# 235     0     0     3               1.0    740000
# 236     0     0     0               0.6    740000
# 237     0     0     0               0.0    430000
# 238     0     0     0               0.0    420000
# 239     0     2     0               0.4    350000
# 240     0     0     0               0.0    160000
# 241     5     2     9               5.6   7050000
# 242     5    17     0               5.8   2360000
# 243     2     2    12               4.6   4370000
# 244     4    -1     0               2.4   1660000
# 245     0     2     1               0.6   3680000
# 246     0     0     0               0.0    750000
# 247     0     1     2               0.6    640000
# 248     5     2     2               1.8    550000
# 249     3     0     0               0.6    770000
# 250     0     0     0               0.4    340000
# 251     0     0     0               0.0    230000
# 252     3    11     3               3.4   6050000
# 253     2     7    10               4.6   4700000
# 254     3     2     6               3.0    790000
# 255     0     0     2               0.8   1930000
# 256     6    11    -2               4.0   2600000
# 257     0     0     0               0.0    350000
# 258     2     4     2               2.8   5210000
# 259     2     3     1               1.8   2380000
# 260    13     3     0               5.8   1800000
# 261     0     0     1               1.0   2000000
# 262     7     8     7               5.2   1530000
# 263     0     0     0               0.0    340000
# 264     0     0     0               0.0    250000
# 265     3     0     2               2.4   5470000
# 266     4     6     4               4.8   1990000
# 267     0     0     1               0.2   3440000
# 268     3    -1     2               2.4   3060000
# 269     9     2     4               3.4   3570000
# 270     1     2     1               1.2    730000
# 271     2     8     0               2.8    730000
# 272     0     0     0               0.8    520000
# 273     0     0     0               1.0    340000
# 274     2     0     2               0.8    330000
# 275     0     0     0               0.0    400000
# 276     7     3     1               4.2   3320000
# 277     2     0     1               1.0   3370000
# 278     2     2     2               4.0    880000
# 279     0     0     0               0.0    580000
# 280     8    11     1               6.4   2070000
# 281     0     0     0               0.0   1180000
# 282     0     0     0               0.0    250000
# 283     8    23     0               8.6   4750000
# 284     5     6     4               4.6   2160000
# 285     5     8     2               1.8   3640000
# 286     6     4     2               3.4   2480000
# 287     0     0     0               1.0   1280000
# 288     0     0     0               0.0   1520000
# 289     0     3     2               1.0    800000
# 290     0     0     0               0.0    420000
# 291     0     0     0               0.0    690000
# 292     0    12    10               8.2  11480000
# 293     0     0     0               0.0    290000
# 294     2     8     9               5.6  10790000
# 295     2     2     6               2.8   3040000
# 296     4     4     3               3.8   5070000
# 297     0     0     1               1.6   2200000
# 298     0     0     2               0.4   2870000
# 299     4     2     0               2.2   1280000
# 300     6     4     0               2.4   1400000
# 301     0     0     2               0.4    960000
# 302     1     0     0               1.8    950000
# 303     0     0     0               0.0    480000
# 304     0     0     0               1.0    350000
# 305     0     2     0               1.2    370000
# 306     0     0     0               0.0    700000
# 307    11     9     9              12.2   9970000
# 308     3    10     2               6.8  10360000
# 309     1     0     2               0.6   4660000
# 310     7    -4     0               2.6   3750000
# 311     0     0     2               0.4    460000
# 312     3     2     6               4.8   4960000
# 313     0     0     2              -0.4   5800000
# 314     1     2     0               2.0   2910000
# 315     2     3     3               2.8    880000
# 316     0     1     2               0.6   1280000
# 317     4     0     2               3.2   1930000
# 318     0     0     0               0.0    340000
# 319     0     0     0               0.0    360000
# 320     0     0     0               0.0    690000
# 321     4     1    -9               0.2  17320000
# 322     0     0     2               1.8   8850000
# 323     0     0     5               4.0   5390000
# 324     4     2     4               3.6   3680000
# 325     0     0     2               0.8   5540000
# 326     2     0     3               2.4   3050000
# 327     5     0     0               2.2   1460000
# 328     0     3     0               1.0    560000
# 329     4     2     0               1.6    620000
# 330     0     0     0               0.0    310000
# 331     0     0     0               0.0    310000
# 332     0     0     0               0.0   1400000
# 333     2     4    11               4.2  11120000
# 334     2     2     3               2.8   5240000
# 335     4     1     1               2.0   3160000
# 336     0     0     0               0.0   1510000
# 337     0     0     0               0.0    470000
# 338     4    12     4               4.0   4150000
# 339     0     0     0               0.0   1120000
# 340     4     8     4               4.8   5850000
# 341     2     2     9               5.2   2360000
# 342     6     0     2               3.0   4640000
# 343     3     0     7               3.0   3950000
# 344     6     0     1               0.6   2030000
# 345     0    16     0               3.2   1890000
# 346     2     5     3               3.0   1580000
# 347     0     0     0               0.4   1870000
# 348     0     5     0               1.0    510000
# 349     0     0     0               0.8    780000
# 350     5     7     8               7.4  13890000
# 351     0     0     0               0.6  10790000
# 352     3     5     5               3.4   6700000
# 353     4     4     4               3.0   4270000
# 354     5     5     2               3.6   5450000
# 355     0     0     0               0.8   3940000
# 356     3     4     4               3.2   2540000
# 357     2     2     9               4.6   3370000
# 358     0     0     0               0.4    610000
# 359     0     4     0               1.0    820000
# 360     2    12    20               6.8  15980000
# 361     2     3     2               1.8   5030000
# 362     4     2     0               1.2   3240000
# 363     6     5    10               6.4   2770000
# 364     0     0     0               0.0   1420000
# 365     0     0     0               0.0    270000
# 366     0     0     0               0.0    210000
# 367     7     0     6               4.0   5910000
# 368     5     1     0               2.2   5010000
# 369     5     0     0               3.0   2820000
# 370     0     0     0               0.0   3700000
# 371     0     2     0               1.8   1680000
# 372     0     6     1               3.0   1480000
# 373     2     2     2               2.2   1940000
# 374     0     0     0               0.0   2220000
# 375     5    12     2               3.8    670000
# 376     2     3     0               1.0    470000
# 377     0     0     0               0.0    310000
# 378     0     0     0               0.0    160000
# 379     2    10    17               8.6  12320000
# 380     3     0     2               1.6   1070000
# 381     0     3     1               1.6   1330000
# 382     2     0     0               0.8    900000
# 383    -1     0     1               1.4   1220000
# 384     1     4     0               1.8    420000
# 385     0     0     0               0.0    460000
# 386     0     0     0               0.0    210000
# 387     2    11    19               7.4  10940000
# 388     8     4     7               4.6   4910000
# 389     8     4     0               3.6   7200000
# 390     0     0     0               0.0    800000
# 391     0     2     2               3.0   2760000
# 392     0     0     0               0.0    340000
# 393     4     4     0               3.4   4230000
# 394     0     4     4               2.8   2620000
# 395     5     6     2               2.8   1000000
# 396     5     2     0               1.8   1290000
# 397     0     0     0               0.2   2560000
# 398     0     0     0               0.0    860000
# 399     0     0     2               0.4    360000
# 400     0     0     0               0.0    230000
# 401     0     0     2               0.4    190000
# 402     8     2     5               4.4   3090000
# 403     4     4     6               3.8   2010000
# 404     4     6     3               3.8   1580000
# 405     1     2     4               3.2   1800000
# 406     2     5     3               2.8   1240000
# 407     2     0     0               1.2    780000
# 408     2     2     1               1.6   1120000
# 409     2     1     2               2.2    940000
# 410     0     2     0               0.4    530000
# 411     5     9     3               7.4  12910000
# 412     3     2     2               1.8   1090000
# 413     0     0     0               0.6    780000
# 414     0     0     2               0.8    650000
# 415    -1     5    13               3.6   2330000
# 416     0     0     0               0.0    220000
# 417     2     5     5               2.6   3990000
# 418     0     4     5               2.2   1410000
# 419     1     0     0               1.2   1340000
# 420     4     5     7               3.2    650000
# 421     0     0     0               0.0    880000
# 422     0     2     6               1.8    500000
# 423     0    11     0               2.4    720000
# 424     0     1     0               0.2    330000
# 425     6     4     4               3.6   3150000
# 426     0     7     5               3.2   2300000
# 427     5     5     7               3.4   1920000
# 428     0    -3     0               0.2   1880000
# 429     6     0     0               2.4   1170000
# 430     2     0     0               0.8    580000
# 431     2     0     0               0.4    280000
# 432     0     0     2               1.0    360000
# 433     0     4     2               1.2    300000
# 434     0     0     0               0.0    400000
# 435     2     0     2               2.0   4240000
# 436     0     2     0               1.0   1770000
# 437     0     2     0               0.4    820000
# 438     0     0     3               1.4    420000
# 439     0     0     0               0.0    600000
# 440     0     0     0               0.0   2610000
# 441    11     6     3               4.6   1640000
# 442     0     0     0               0.0    190000
# 443     4     0     1               1.8   4660000
# 444     2     4     0               2.0   2310000
# 445     2     4     5               3.4   1350000
# 446     6     3     2               3.0   1010000
# 447     0     0     0              -0.6   1390000
# 448     0     0     0               0.0   1450000
# 449     0     6     0               1.6    540000
# 450     0     0     1               0.2    480000
# 451     0     0     0               0.0    220000
# 452     8     1     4               4.4   3810000
# 453     2     9     2               3.6   1540000
# 454    10     4     2               4.2   1200000
# 455     0     0     2               1.6   1590000
# 456     6     2     2               3.6    650000
# 457     0     2     1               1.8    870000
# 458     0     0     0               0.2   1900000
# 459     0     0     0               0.0    690000
# 460     2    12     5               4.6   6110000
# 461     6     7     2               4.4   4620000
# 462     2     3     0               1.0   2650000
# 463     5     2     7               2.8    960000
# 464     2     0     0               1.4    650000
# 465     0     0     0               0.0    460000
# 466     2     4     4               3.2   1780000
# 467     1     0     0               1.2   2910000
# 468     0     0     8               1.6   2770000
# 469     5     5     2               4.4   1290000
# 470     4     8     0               4.2   1310000
# 471     0     0     0               0.0    280000
# 472     5     2    15               5.8   6180000
# 473     8     2     5               5.2   5380000
# 474     2     2     2               3.8   3540000
# 475     2     4     2               2.8   3170000
# 476     4     8     5               3.8   3080000
# 477     1     0     0               1.0    640000
# 478     0     0     0               0.4    400000
# 479     0     0     0               0.0    230000
# 480     0     0     0               0.0    280000
# 481     0     0     2               0.4    220000
# 482     0     0     0               0.0    200000
# 483     8     0    15               7.4  18960000
# 484     3     3    12               5.6   9520000
# 485     3     4     2               2.8   3680000
# 486     0     2     0               1.2   1320000
# 487     7     8     3               3.6   5020000
# 488     0     0     0               0.0    830000
# 489     8     6     5               4.6   7180000
# 490     5     0     2               3.8   4500000
# 491     0     0     0               0.0   6450000
# 492     6     6     1               4.4   4320000
# 493     5     5     2               3.2   1440000
# 494     0     4     5               1.8   1090000
# 495     3     3     2               3.0   5260000
# 496     4     0    14               6.8   7680000
# 497     6     2     0               2.2   6170000
# 498     6    11     5               4.6   2610000
# 499     2     4     2               3.4   3080000
# 500     0     1     0               0.6   1680000
# 501     1     2     0               1.6   1490000
# 502     0     2     5               1.4    510000
# 503     0     0     0               0.0    310000
# 504     0     0     0               0.0   7390000
# 505     2     2     2               3.4  12320000
# 506    11     0     8               6.4  11930000
# 507     0     0     0               0.0   7340000
# 508     0     0     0               0.4   1410000
# 509     2     2     2               2.2   3050000
# 510     0     0     0               0.8    730000
# 511     0     0     2               0.4    350000

# %%
df_comunio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Team_id                 512 non-null    int64
#  1   Team                    512 non-null    object
#  2   Player                  512 non-null    object
#  3   Position                512 non-null    object
#  4   Matches_Played          512 non-null    int64
#  5   On_start_%              512 non-null    int64
#  6   Goals_/_Goals_Received  512 non-null    int64
#  7   Assists                 512 non-null    int64
#  8   Total_Points            512 non-null    int64
#  9   Points_Average          512 non-null    float64
#  10  Last_5_games_points     512 non-null    object
#  11  J_14                    512 non-null    int64
#  12  J_15                    512 non-null    int64
#  13  J_16                    512 non-null    int64
#  14  J_17                    512 non-null    int64
#  15  J_18                    512 non-null    int64
#  16  Avg_last_5_games        512 non-null    float64
#  17  Value                   512 non-null    int64
# dtypes: float64(2), int64(12), object(4)
# memory usage: 72.1+ KB
